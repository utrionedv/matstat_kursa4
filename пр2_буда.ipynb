# %% [markdown]
# <a href="https://colab.research.google.com/github/utrionedv/matstat_kursa4/blob/main/%D0%BF%D1%802_%D0%B1%D1%83%D0%B4%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df1['1'] = pd.read_csv("/content/1.txt", header=None)
df2['2'] = pd.read_csv("/content/2.txt", header=None)
df1['3'] = pd.read_csv("/content/3.txt", header=None)
df2['4'] = pd.read_csv("/content/4.txt", header=None)

# %% [markdown]
# ## Ряд 1

# %%
print('1. Рассчитать точечные оценки математического ожидания и стандартного отклонения:')
print()

mean1 = df1['1'].mean()
print('Математическое ожидание 1 ряда: ', mean1)
std1 = df1['1'].std(ddof = 1)
print('Cтандартное отклонение: 1 ряда: ', std1)

print()
print()
print('2. Найти границы доверительного интервала мат. ожидания по правилу нормального распределения, используя таблицу критических значений функции Лапласа:')
print()

xy = 1.96
delta = xy * (std1 / (len(df1['1']) ** 0.5))
print('Интервал мат. ожидания 1 ряда (по правилу нормального распределения): [', mean1 - delta, '; ', mean1 + delta, ']')
# print(delta)

print()
print()
print('3. По правилу t-распределения Стьюдента, используя таблицу критических значений 𝑡𝛾,𝑛 t-распределения при значении уверенности 𝛾 = 0.95:')
print()

t99 = 1.98
delta = t99 * (std1 / (len(df1['1']) ** 0.5))
print('Интервал мат. ожидания 1 ряда (по правилу t-распределения Стьюдента): [', mean1 - delta, '; ', mean1 + delta, ']')
# print(delta)

print()
print()
print('Найти границы доверительного интервала для среднеквадратического отклонения по оценке 𝜒2-распределения при значении уверенности 𝛾 = 0.95:')
print()
X99_1 = 128.42
X99_2 = 73.36

print('Доверительный интервал среднеквадратического отклонения 1 ряда: [',
 (std1 * ((len(df1['1']) - 1) ** 0.5)) / (X99_1 ** 0.5), '; ', (std1 * ((len(df1['1']) - 1) ** 0.5)) / (X99_2 ** 0.5), ']')
# Out:
# 1. Рассчитать точечные оценки математического ожидания и стандартного отклонения:
#
# Математическое ожидание 1 ряда:  69.4645553502391
# Cтандартное отклонение: 1 ряда:  2.0877085068271484
#
#
# 2. Найти границы доверительного интервала мат. ожидания по правилу нормального распределения, используя таблицу критических значений функции Лапласа:
#
# Интервал мат. ожидания 1 ряда (по правилу нормального распределения): [ 69.05536448290097 ;  69.87374621757722 ]
#
#
# 3. По правилу t-распределения Стьюдента, используя таблицу критических значений 𝑡𝛾,𝑛 t-распределения при значении уверенности 𝛾 = 0.95:
#
# Интервал мат. ожидания 1 ряда (по правилу t-распределения Стьюдента): [ 69.05118906588731 ;  69.87792163459088 ]
#
#
# Найти границы доверительного интервала для среднеквадратического отклонения по оценке 𝜒2-распределения при значении уверенности 𝛾 = 0.95:
#
# Доверительный интервал среднеквадратического отклонения 1 ряда: [ 1.83303655275202 ;  2.425257167834041 ]

# %% [markdown]
# ## Ряд 2

# %%
print('1. Рассчитать точечные оценки математического ожидания и стандартного отклонения:')
print()

mean2 = df2['2'].mean()
print('Математическое ожидание 2 ряда: ', mean2)
std2 = df2['2'].std(ddof = 1)
print('Cтандартное отклонение: 2 ряда: ', std2)

print()
print()
print('2. Найти границы доверительного интервала мат. ожидания по правилу нормального распределения, используя таблицу критических значений функции Лапласа:')
print()

xy = 1.96
delta = xy * (std2 / (len(df2['2']) ** 0.5))
print('Интервал мат. ожидания 2 ряда (по правилу нормального распределения): [', mean2 - delta, '; ', mean2 + delta, ']')
print(delta)

print()
print()
print('3. По правилу t-распределения Стьюдента, используя таблицу критических значений 𝑡𝛾,𝑛 t-распределения при значении уверенности 𝛾 = 0.95:')
print()

t9 = 2.26
delta = t9 * (std2 / (len(df2['2']) ** 0.5))
print('Интервал мат. ожидания 2 ряда (по правилу t-распределения Стьюдента): [', mean2 - delta, '; ', mean2 + delta, ']')
print(delta)

print()
print()
print('Найти границы доверительного интервала для среднеквадратического отклонения по оценке 𝜒2-распределения при значении уверенности 𝛾 = 0.95:')
print()

X9_1 = 19.02
X9_2 = 2.7
print('Доверительный интервал среднеквадратического отклонения 2 ряда: [',
 (std2 * ((len(df2['2']) - 1) ** 0.5)) / (X9_1 ** 0.5), '; ', (std2 * ((len(df2['2']) - 1) ** 0.5)) / (X9_2 ** 0.5), ']')
# Out:
# 1. Рассчитать точечные оценки математического ожидания и стандартного отклонения:
#
# Математическое ожидание 2 ряда:  47.03700095908015
# Cтандартное отклонение: 2 ряда:  1.507387827116852
#
#
# 2. Найти границы доверительного интервала мат. ожидания по правилу нормального распределения, используя таблицу критических значений функции Лапласа:
#
# Интервал мат. ожидания 2 ряда (по правилу нормального распределения): [ 46.10271230430348 ;  47.971289613856825 ]
# 0.9342886547766697
#
#
# 3. По правилу t-распределения Стьюдента, используя таблицу критических значений 𝑡𝛾,𝑛 t-распределения при значении уверенности 𝛾 = 0.95:
#
# Интервал мат. ожидания 2 ряда (по правилу t-распределения Стьюдента): [ 45.959708938776444 ;  48.11429297938386 ]
# 1.0772920203037109
#
#
# Найти границы доверительного интервала для среднеквадратического отклонения по оценке 𝜒2-распределения при значении уверенности 𝛾 = 0.95:
#
# ...

# %% [markdown]
# ## Ряд 3

# %%
print('1. Рассчитать точечные оценки математического ожидания и стандартного отклонения:')
print()

mean3 = df1['3'].mean()
print('Математическое ожидание 3 ряда: ', mean3)
std3 = df1['3'].std(ddof = 1)
print('Cтандартное отклонение: 3 ряда: ', std3)

print()
print()
print('2. Найти границы доверительного интервала мат. ожидания по правилу нормального распределения, используя таблицу критических значений функции Лапласа:')
print()

xy = 1.96
delta = xy * (std3 / (len(df1['3']) ** 0.5))
print('Интервал мат. ожидания 3 ряда (по правилу нормального распределения): [', mean3 - delta, '; ', mean3 + delta, ']')
print(delta)

print()
print()
print('3. По правилу t-распределения Стьюдента, используя таблицу критических значений 𝑡𝛾,𝑛 t-распределения при значении уверенности 𝛾 = 0.95:')
print()

t99 = 1.98
delta = t99 * (std1 / (len(df1['3']) ** 0.5))
print('Интервал мат. ожидания 3 ряда (по правилу t-распределения Стьюдента): [', mean3 - delta, '; ', mean3 + delta, ']')
print(delta)

print()
print()
print('Найти границы доверительного интервала для среднеквадратического отклонения по оценке 𝜒2-распределения при значении уверенности 𝛾 = 0.95:')
print()
X99_1 = 128.42
X99_2 = 73.36

print('Доверительный интервал среднеквадратического отклонения 1 ряда: [',
 (std3 * ((len(df1['3']) - 1) ** 0.5)) / (X99_1 ** 0.5), '; ', (std3 * ((len(df1['3']) - 1) ** 0.5)) / (X99_2 ** 0.5), ']')
# Out:
# 1. Рассчитать точечные оценки математического ожидания и стандартного отклонения:
#
# Математическое ожидание 3 ряда:  52.3222465610357
# Cтандартное отклонение: 3 ряда:  9.012385995697892
#
#
# 2. Найти границы доверительного интервала мат. ожидания по правилу нормального распределения, используя таблицу критических значений функции Лапласа:
#
# Интервал мат. ожидания 3 ряда (по правилу нормального распределения): [ 50.55581890587891 ;  54.08867421619249 ]
# 1.7664276551567868
#
#
# 3. По правилу t-распределения Стьюдента, используя таблицу критических значений 𝑡𝛾,𝑛 t-распределения при значении уверенности 𝛾 = 0.95:
#
# Интервал мат. ожидания 3 ряда (по правилу t-распределения Стьюдента): [ 51.908880276683924 ;  52.73561284538747 ]
# 0.41336628435177536
#
#
# Найти границы доверительного интервала для среднеквадратического отклонения по оценке 𝜒2-распределения при значении уверенности 𝛾 = 0.95:
#
# ...

# %% [markdown]
# ## Ряд 4

# %%
print('1. Рассчитать точечные оценки математического ожидания и стандартного отклонения:')
print()

mean4 = df2['4'].mean()
print('Математическое ожидание 4 ряда: ', mean4)
std4 = df2['4'].std(ddof = 1)
print('Cтандартное отклонение: 4 ряда: ', std4)

print()
print()
print('2. Найти границы доверительного интервала мат. ожидания по правилу нормального распределения, используя таблицу критических значений функции Лапласа:')
print()

xy = 1.96
delta = xy * (std4 / (len(df2['4']) ** 0.5))
print('Интервал мат. ожидания 4 ряда (по правилу нормального распределения): [', mean4 - delta, '; ', mean4 + delta, ']')
print(delta)

print()
print()
print('3. По правилу t-распределения Стьюдента, используя таблицу критических значений 𝑡𝛾,𝑛 t-распределения при значении уверенности 𝛾 = 0.95:')
print()

t9 = 2.26
delta = t9 * (std4 / (len(df2['4']) ** 0.5))
print('Интервал мат. ожидания 4 ряда (по правилу t-распределения Стьюдента): [', mean4 - delta, '; ', mean4 + delta, ']')
print(delta)

print()
print()
print('Найти границы доверительного интервала для среднеквадратического отклонения по оценке 𝜒2-распределения при значении уверенности 𝛾 = 0.95:')
print()

X9_1 = 19.02
X9_2 = 2.7
print('Доверительный интервал среднеквадратического отклонения 4 ряда: [',
 (std4 * ((len(df2['4']) - 1) ** 0.5)) / (X9_1 ** 0.5), '; ', (std4 * ((len(df2['4']) - 1) ** 0.5)) / (X9_2 ** 0.5), ']')
# Out:
# 1. Рассчитать точечные оценки математического ожидания и стандартного отклонения:
#
# Математическое ожидание 4 ряда:  51.29100760831015
# Cтандартное отклонение: 4 ряда:  7.108628962635791
#
#
# 2. Найти границы доверительного интервала мат. ожидания по правилу нормального распределения, используя таблицу критических значений функции Лапласа:
#
# Интервал мат. ожидания 4 ряда (по правилу нормального распределения): [ 46.885033729968214 ;  55.69698148665209 ]
# 4.40597387834194
#
#
# 3. По правилу t-распределения Стьюдента, используя таблицу критических значений 𝑡𝛾,𝑛 t-распределения при значении уверенности 𝛾 = 0.95:
#
# Интервал мат. ожидания 4 ряда (по правилу t-распределения Стьюдента): [ 46.21064997307914 ;  56.37136524354116 ]
# 5.080357635231012
#
#
# Найти границы доверительного интервала для среднеквадратического отклонения по оценке 𝜒2-распределения при значении уверенности 𝛾 = 0.95:
#
# ...
